# %% [markdown]
# ## Download and decompress dataset
# Using the "Subscription Boxes" set for testing data manipulation because it's small.

# %%
# %%capture
# !curl -O https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Electronics.jsonl.gz
# !curl -O https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/meta_categories/meta_Electronics.jsonl.gz
# !curl --create-dirs --output-dir data -O https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Subscription_Boxes.jsonl.gz
# !curl --create-dirs --output-dir data -O https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/meta_categories/meta_Subscription_Boxes.jsonl.gz

# !gunzip data/Subscription_boxes.jsonl.gz
# !gunzip data/meta_Subscription_boxes.jsonl.gz

# %%
import json

file = "data/Subscription_boxes.jsonl" # e.g., "All_Beauty.jsonl", downloaded from the `review` link above
with open(file, 'r') as fp:
    for line in fp:
        print(json.loads(line.strip()))
